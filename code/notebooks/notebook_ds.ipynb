# %%
import pandas as pd
kernel_stats = pd.read_csv('libraries_by_python_version2.csv')
kernel_stats
# Out:
#    total_count            rule
# 0           11          worker
# 1          185  police officer
# 2          673  police officer
# 3          244       developer
# 4          734     firefighter

# %%
import matplotlib.pyplot as plt
plt.pie(kernel_stats['total_count'], labels=kernel_stats['rule'])
plt.show()
